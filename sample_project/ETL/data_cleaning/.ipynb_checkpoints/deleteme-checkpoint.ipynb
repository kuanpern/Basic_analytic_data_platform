# %%
# %run ../ETL_main.py --indir ../../data/dump/ --logfile test.log --dbpath test.db

# %%
df_final
# Out:
#     Daily Rainfall Total (mm)    Datetime                      Station  \
# 0                           0  2018-11-02               Alexandra Road
# 1                           0  2018-11-02               Alexandra Road
# 2                           0  2018-11-02          Ang Mo Kio Avenue 5
# 3                           0  2018-11-02          Ang Mo Kio Avenue 5
# 4                           0  2018-11-02                  Banyan Road
# 5                           0  2018-11-02                  Banyan Road
# 6                           0  2018-11-02               Buangkok Green
# 7                           0  2018-11-02               Buangkok Green
# 8                           0  2018-11-02           Bukit Panjang Road
# 9                           0  2018-11-02           Bukit Panjang Road
# 10                          0  2018-11-02             Bukit Timah Road
# 11                          0  2018-11-02             Bukit Timah Road
# ...

# %%
df_final = df_final.drop_duplicates(subset=['Station', 'Datetime'], keep='last')

# %%
len(df_final)
# Out:
# 50

# %%
df_final
# Out:
#     Daily Rainfall Total (mm)    Datetime                      Station  \
# 1                           0  2018-11-02               Alexandra Road
# 3                           0  2018-11-02          Ang Mo Kio Avenue 5
# 5                           0  2018-11-02                  Banyan Road
# 7                           0  2018-11-02               Buangkok Green
# 9                           0  2018-11-02           Bukit Panjang Road
# 11                          0  2018-11-02             Bukit Timah Road
# 13                          0  2018-11-02             Chai Chee Street
# 15                          0  2018-11-02       Choa Chu Kang Avenue 4
# 17                          0  2018-11-02           Choa Chu Kang Road
# 19                          0  2018-11-02                Clementi Road
# 21                          0  2018-11-02             Corporation Road
# 23                          0  2018-11-02           East Coast Parkway
# ...
